# %% [markdown]
# <a href="https://colab.research.google.com/github/Aldo-CL/Bases-Datos/blob/main/Modelado_Logico_y_Modelado_fisico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# En esta clase, te doy la bienvenida al curso de modelado de bases de datos relacionales. Aprenderás a pasar de un modelo conceptual (diagrama entidad-relación) a un modelo lógico y, finalmente, a un modelo físico. Usaremos como referencia un modelo de base de datos relacional de un curso anterior y verás cómo las entidades se convierten en tablas con dominios y restricciones.

# %% [markdown]
# **Diversos Modelos**
#
# En esta clase, se explica el proceso de modelado de bases de datos, que consta de tres fases: modelo conceptual, modelo lógico y modelo físico.
#
# Modelo Conceptual: Se crea un diagrama entidad-relación.
# Modelo Lógico: Se convierte el modelo conceptual en un modelo lógico, utilizando relaciones (tablas) y campos con restricciones y cardinalidad.
# Modelo Físico: Se elabora un modelo físico con herramientas como SQL Power Architect, que muestra el dominio de los atributos (columnas), si acepta valores nulos y el tipo de restricción.
# En resumen, se pasa de un modelo general a uno más detallado y específico, listo para ser implementado en una base de datos relacional. En el próximo video, se comenzará a trabajar en la elaboración del modelo lógico.

# %% [markdown]
# **Presentando el modelo logico**
#
# El modelo lógico de datos es creado a partir de las descripciones de los datos representadas en un modelo conceptual. Este describe cómo los datos serán almacenados en la base de datos, identificando las entidades, los atributos, las claves principales y foráneas y sus relaciones.
#
# Hay dos formas que podemos utilizar para representar el modelo lógico: La forma horizontal o la forma vertical. Durante el curso fue utilizada la representación vertical, donde los atributos (que más adelante serán llamados campos) son representados uno abajo del otro, los atributos clave son identificados y las relaciones son representadas a través de líneas uniendo una relación a la otra:
#
# 10.jpg
#
# En la forma horizontal, los atributos (campos) son presentados uno al lado del otro, los atributos clave son subrayados en las relaciones y las relaciones son representadas a través de una flecha, que sale de la relación dependiente y llega a la relación propietaria. Ya las cardinalidades no son representadas, como en el ejemplo a continuación:
#
# 11.jpg
#
# Las dos formas son válidas y pueden ser utilizadas para representar el modelo lógico de datos. Normalmente la forma más utilizada es la forma vertical, por ser semejante a la representación final de las relaciones en una base de datos.

# %% [markdown]
# ![10.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![11.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Modelado Logico**
#
# En esta clase, se explica cómo pasar de un diagrama entidad-relación a un modelo lógico utilizando la herramienta diagrams.net.
#
# Aquí tienes un resumen de los puntos clave:
#
# Herramienta: Se utilizará diagrams.net, la misma herramienta del curso anterior, para crear el modelo lógico.
# Acceso a diagrams.net: Se muestra cómo acceder a diagrams.net a través del navegador y cómo abrir el diagrama entidad-relación previamente creado.
# Terminología: Se aclara que en el modelo lógico se habla de "relaciones" en lugar de "entidades" (como en el diagrama entidad-relación), y que en el modelo físico se hablará de "tablas". Aunque son lo mismo, es importante usar la terminología correcta en cada etapa.
# Creación de un nuevo diagrama: Se explica cómo crear un nuevo diagrama en blanco en diagrams.net para construir el modelo lógico.
# Migración del diagrama entidad-relación: Se indica que en el próximo video se mostrará cómo trasladar la información del diagrama entidad-relación al modelo lógico, creando las relaciones correspondientes.
